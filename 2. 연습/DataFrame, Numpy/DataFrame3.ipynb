# %%
import numpy as np
import pandas as pd
a = pd.Series(np.arange(5.0), index = list('abcde'))
a
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
del a['a']
a
# Out:
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64

# %%
a.drop('c')
# Out:
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %%
a.drop(['e', 'd'])
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
b = pd.DataFrame(np.arange(16).reshape(4, 4), index = list('abcd'), columns = list('abcd'.upper()))
b
# Out:
#     A   B   C   D
# a   0   1   2   3
# b   4   5   6   7
# c   8   9  10  11
# d  12  13  14  15

# %%
b.drop(['a', 'c'])
# Out:
#     A   B   C   D
# b   4   5   6   7
# d  12  13  14  15

# %%
b.drop(['A', 'C'], axis = 1)
# Out:
#     B   D
# a   1   3
# b   5   7
# c   9  11
# d  13  15

# %%
b.drop(['a', 'c'], axis = 0)
# Out:
#     A   B   C   D
# b   4   5   6   7
# d  12  13  14  15

# %%
a = [3., 1, 8, 12]
b = [2., 0, 9, 13]
c = [7, 5, 3, 1]
d = [6, 4, 2, 0]

s = pd.DataFrame({'A' : a, 'B' : b, 'C' : c, 'D' : d}, 
              index = list('abcd'))
s
# Out:
#       A     B  C  D
# a   3.0   2.0  7  6
# b   1.0   0.0  5  4
# c   8.0   9.0  3  2
# d  12.0  13.0  1  0

# %%
pd.concat([s[:2], s[:2]], axis = 0)
# Out:
#      A    B  C  D
# a  3.0  2.0  7  6
# b  1.0  0.0  5  4
# a  3.0  2.0  7  6
# b  1.0  0.0  5  4

# %%
pd.concat([s[:2], s[:2]], axis = 1)
# Out:
#      A    B  C  D    A    B  C  D
# a  3.0  2.0  7  6  3.0  2.0  7  6
# b  1.0  0.0  5  4  1.0  0.0  5  4

# %%
s.to_csv('DF.txt', sep = '\t')

# %%
DF = s
DF
# Out:
#       A     B  C  D
# a   3.0   2.0  7  6
# b   1.0   0.0  5  4
# c   8.0   9.0  3  2
# d  12.0  13.0  1  0

# %%
DF.B.sort_index()
# Out:
# a     2.0
# b     0.0
# c     9.0
# d    13.0
# Name: B, dtype: float64

# %%
DF.B.sort_values() #value를 오름차순으로 정렬해줌
# Out:
# b     0.0
# a     2.0
# c     9.0
# d    13.0
# Name: B, dtype: float64

# %%
DF.B.sort_values(ascending = False)
# Out:
# d    13.0
# c     9.0
# a     2.0
# b     0.0
# Name: B, dtype: float64

# %%
DF.B = [0, 0, 4, 4]
DF
# Out:
#       A  B  C  D
# a   3.0  0  7  6
# b   1.0  0  5  4
# c   8.0  4  3  2
# d  12.0  4  1  0

# %%
DF.sort_values(by = 'D')
# Out:
#       A  B  C  D
# d  12.0  4  1  0
# c   8.0  4  3  2
# b   1.0  0  5  4
# a   3.0  0  7  6

# %%
DF.sort_values(by = ['B', 'D'], ascending = [True, False])
# Out:
#       A  B  C  D
# a   3.0  0  7  6
# b   1.0  0  5  4
# c   8.0  4  3  2
# d  12.0  4  1  0

# %%
a = DF.head(3)
a
# Out:
#      A  B  C  D
# a  3.0  0  7  6
# b  1.0  0  5  4
# c  8.0  4  3  2

# %%
b = DF.iloc[::2, ::2]
b
# Out:
#      A  C
# a  3.0  7
# c  8.0  3

# %%
DF.applymap(int)
# Out:
#     A  B  C  D
# a   3  0  7  6
# b   1  0  5  4
# c   8  4  3  2
# d  12  4  1  0

# %%
DF.apply(sum)
# Out:
# A    24.0
# B     8.0
# C    16.0
# D    12.0
# dtype: float64

# %%
DF.describe()
# Out:
#                A         B         C         D
# count   4.000000  4.000000  4.000000  4.000000
# mean    6.000000  2.000000  4.000000  3.000000
# std     4.966555  2.309401  2.581989  2.581989
# min     1.000000  0.000000  1.000000  0.000000
# 25%     2.500000  0.000000  2.500000  1.500000
# 50%     5.500000  2.000000  4.000000  3.000000
# 75%     9.000000  4.000000  5.500000  4.500000
# max    12.000000  4.000000  7.000000  6.000000
