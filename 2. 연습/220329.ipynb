# %%
import pandas as pd

s = pd.Series([11, 28, 72, 3, 5, 8])
s
# Out:
# 0    11
# 1    28
# 2    72
# 3     3
# 4     5
# 5     8
# dtype: int64

# %% [markdown]
# s.values

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
type(s.values)
# Out:
# numpy.ndarray

# %%
pd.Series((11, 28))
# Out:
# 0    11
# 1    28
# dtype: int64

# %%
pd.Series((('a', 2), ('b', 1)))
# Out:
# 0    (a, 2)
# 1    (b, 1)
# dtype: object

# %%
import numpy as np
pd.Series(np.array([1, 2, 1]))
# Out:
# 0    1
# 1    2
# 2    1
# dtype: int64

# %%
pd.Series({'a' : 'abd', 'b' : np.arange(4)})
# Out:
# a             abd
# b    [0, 1, 2, 3]
# dtype: object

# %%
pd.Series(list('abc'))
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
pd.Series({'a' : np.arange(4).reshape(2, 2), 'b' : np.arange(4)})
# Out:
# a    [[0, 1], [2, 3]]
# b        [0, 1, 2, 3]
# dtype: object

# %%
a = pd.Series([11, 12, 13], index = range(1, 4))
a
# Out:
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
a.index
# Out:
# RangeIndex(start=1, stop=4, step=1)

# %%
type(a.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
a[1]
# Out:
# 11

# %%
a[1:3]
# Out:
# 2    12
# 3    13
# dtype: int64

# %%
a
# Out:
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
a[1] = None
a
# Out:
# 1     NaN
# 2    12.0
# 3    13.0
# dtype: float64

# %%
a[1:3] = [10, np.nan]
a
# Out:
# 1     NaN
# 2    10.0
# 3     NaN
# dtype: float64

# %%
a.fillna(0)
# Out:
# 1     0.0
# 2    10.0
# 3     0.0
# dtype: float64

# %%
a.fillna(0).astype('int')
# Out:
# 1     0
# 2    10
# 3     0
# dtype: int64

# %%
np.array([np.nan, 2, 1])
# Out:
# array([nan,  2.,  1.])

# %%
np.array([None, 2, 1])
# Out:
# array([None, 2, 1], dtype=object)

# %%
b = pd.Series([11, 12, 13], index = list('abc'))
b
# Out:
# a    11
# b    12
# c    13
# dtype: int64

# %%
b[0]
# Out:
# 11

# %%
b['a']
# Out:
# 11

# %%
b['c':'a']
# Out:
# Series([], dtype: int64)

# %%
b.index = ['b', 'c', 'c']
b
# Out:
# b    11
# c    12
# c    13
# dtype: int64

# %%
b['c']
# Out:
# c    12
# c    13
# dtype: int64

# %%
b['b':'c']
# Out:
# b    11
# c    12
# c    13
# dtype: int64

# %%
b
# Out:
# b    11
# c    12
# c    13
# dtype: int64

# %%
b.index = range(1, 4)
b
# Out:
# 1    11
# 2    12
# 3    13
# dtype: int64

# %%
b.index = [('a',), ('a',), ('a',)]
b
# Out:
# (a,)    11
# (a,)    12
# (a,)    13
# dtype: int64

# %%
c = pd.Series([11, 12, 13], index = ['a', 'b', 'b'])
c
# Out:
# a    11
# b    12
# b    13
# dtype: int64

# %%
c['b']
# Out:
# b    12
# b    13
# dtype: int64

# %%
c['b'] = 3
c
# Out:
# a    11
# b     3
# b     3
# dtype: int64

# %% [markdown]
# ## Exercise 1

# %%
A = pd.Series(['ab', 'ba', 'ab', 'ba', 'ab'], [1, 2, 2, 1, 3])
A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e115962dbdee> in <module>()
# ----> 1 A = pd.Series(['ab', 'ba', 'ab', 'ba', 'ab'], [1, 2, 2, 1, 3])
#       2 A
#
# NameError: name 'pd' is not defined

# %%
A[2]
# Out:
# 2    ba
# 2    ab
# dtype: object

# %% [markdown]
# ## Exercise 2

# %%
A[A == 'ab']
# Out:
# 1    ab
# 2    ab
# 3    ab
# dtype: object

# %% [markdown]
# ## Exercise 3

# %%
A = pd.Series(list('abc') * 2, index = [k for j in [[i] * i 
                                                    for i in range(1, 4) for k in j]

# %% [markdown]
# ## Exercise 4

# %%
A[[3, 2]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-26e3bbfa75b5> in <module>()
# ----> 1 A[[3, 2]]
#
# NameError: name 'A' is not defined

# %%
A[0:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9f27e36a8b53> in <module>()
# ----> 1 A[0:5]
#
# NameError: name 'A' is not defined
